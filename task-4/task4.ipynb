# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading data set

# %%
df=pd.read_csv('data_science_student_marks.csv')
df.head()
# Out:
#    student_id location  age  sql_marks  excel_marks  python_marks  \
# 0           4   Sydney   24         95           99            87
# 1           5    Tokyo   24         99           95            89
# 2           6   Berlin   22         72           70            99
# 3           7   London   23         97           90            74
# 4           8    Tokyo   22         91           71            79
#
#    power_bi_marks  english_marks
# 0              82             75
# 1              86             82
# 2              79             77
# 3              72             85
# 4              80             75

# %% [markdown]
# ## Checking null values in data

# %%
df.isnull().sum()
# Out:
# student_id        0
# location          0
# age               0
# sql_marks         0
# excel_marks       0
# python_marks      0
# power_bi_marks    0
# english_marks     0
# dtype: int64

# %% [markdown]
# ## Checking duplicated values in data

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Checkin correlation of two columns

# %%
np.corrcoef(df['excel_marks'],df['power_bi_marks'])
# Out:
# array([[1.       , 0.0295196],
#        [0.0295196, 1.       ]])

# %%
np.corrcoef(df['python_marks'],df['power_bi_marks'])
# Out:
# array([[ 1.        , -0.00921348],
#        [-0.00921348,  1.        ]])

# %%
df.describe()
# Out:
#        student_id         age   sql_marks  excel_marks  python_marks  \
# count  497.000000  497.000000  497.000000   497.000000    497.000000
# mean   252.000000   21.380282   84.661972    85.384306     85.388330
# std    143.615807    2.205714    8.745415     8.782497      8.878668
# min      4.000000   18.000000   70.000000    70.000000     70.000000
# 25%    128.000000   20.000000   78.000000    78.000000     77.000000
# 50%    252.000000   21.000000   85.000000    86.000000     86.000000
# 75%    376.000000   23.000000   92.000000    93.000000     94.000000
# max    500.000000   25.000000  100.000000   100.000000    100.000000
#
#        power_bi_marks  english_marks
# count      497.000000     497.000000
# mean        84.545272      84.824950
# std          8.903066       9.060479
# min         70.000000      70.000000
# 25%         77.000000      77.000000
# 50%         84.000000      85.000000
# 75%         92.000000      93.000000
# max        100.000000     100.000000

# %% [markdown]
# ## Finding average age

# %%
df['age'].mean()
# Out:
# np.float64(21.380281690140844)

# %%
df['sql_marks'].max()
# Out:
# 100

# %% [markdown]
# ## Data visulization

# %%
plt.figure(figsize=(8,4))
plt.scatter(df['student_id'],df['sql_marks'], color='blue')
plt.xlabel('Student ID')
plt.ylabel('sql_marks')
plt.title('Scatter Chart of Sql marks By Student id')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,3))
plt.bar(df['location'],df['power_bi_marks'])
plt.xticks(rotation=45)
plt.xlabel('location')
plt.ylabel('Power bi Marks')
plt.title('Location vs Power bi marks')
plt.show()

# %%
g=df.groupby('english_marks')['english_marks'].count()
g
# Out:
# english_marks
# 70     25
# 71     18
# 72     17
# 73     15
# 74     12
# 75     14
# 76     10
# 77     19
# 78     15
# 79     16
# 80     15
# 81     15
# 82     16
# 83     16
# 84     23
# 85     16
# 86     12
# 87     21
# 88     20
# 89      7
# 90     13
# 91     17
# 92     16
# 93     13
# 94     13
# 95     24
# 96     20
# 97     15
# 98     15
# 99     18
# 100    11
# Name: english_marks, dtype: int64

# %%
plt.figure(figsize=(8,4))
plt.plot(g.index,g.values,label='English_marks',color='blue',marker='o')
plt.xlabel('marks')
plt.ylabel('count of marks')
plt.title('Line plot of count of marks')
plt.show()

# %%
s=df.groupby('sql_marks')['sql_marks'].count()

# %%
plt.figure(figsize=(8,4))
plt.plot(s.index,s.values,label='English_marks',color='green',marker='o')
plt.xlabel('sql marks')
plt.ylabel('count of marks')
plt.title('Line plot of count of marks of sql')
plt.show()

# %%
e=df.groupby('excel_marks')['excel_marks'].count()

# %%
plt.figure(figsize=(8,4))
plt.plot(e.index,e.values,label='English_marks',color='black',marker='o')
plt.xlabel('excel marks')
plt.ylabel('count of marks')
plt.title('Line plot of count of marks of excel')
plt.show()
